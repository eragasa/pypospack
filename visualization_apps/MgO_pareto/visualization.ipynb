# %% [markdown]
# imports go here

# %%
import os
import bokeh.io
import visualization_gene as vizgraph
data_dir = 'data'
data_fname = 'culled_009.out'

bokeh.io.output_notebook()
fname = os.path.join(os.getcwd(),data_dir,data_fname)
viz = vizgraph.VisualizationDemo()
viz.load_data_file(
    fname = os.path.join(os.getcwd(),data_dir,data_fname))
#viz.start_bokeh_server()
viz.setup_bokeh_frame()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="33225325-fa90-4148-a787-24924803a57e">Loading BokehJS ...</span>
#     </div>
# chrg_Mg chrg_O
# MgO_NaCl.a0.err MgO_NaCl.c11.err
#     <div class="bk-root">
#         <div class="plotdiv" id="06e29fe2-7857-4582-94e5-d21ca7c0b3ce"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
# ...
